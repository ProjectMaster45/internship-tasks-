# %% [markdown]
# # Car Task

# %% [markdown]
# ## Q.1 Load the dataset and print first 10 rows.

# %%
import pandas as pd

df = pd.read_csv(
    r"C:\Users\samik\AppData\Local\Packages\5319275A.WhatsAppDesktop_cv1g1gvanyjgm\LocalState\sessions\F41B265465FB5BCF8E657AFD290F973D9F365E0D\transfers\2026-24\BMW Car Task\BMW Car Task\bmw_car_data.csv"
)

df.head(10)
# Out:
#    ID Model_Name      Variant  Year Fuel_Type    Transmission  Engine_CC  \
# 0   1         X5       xDrive  2019  Electric          Manual       1496
# 1   2         X5  Luxury Line  2016  Electric       Automatic       1496
# 2   3         Z4      M Sport  2012  Electric  Semi-Automatic       4395
# 3   4         X7      M Sport  2013    Hybrid  Semi-Automatic       4395
# 4   5         X7       xDrive  2010  Electric          Manual       2993
# 5   6         X1      M Sport  2012    Petrol          Manual       2993
# 6   7         M3     Standard  2014    Hybrid  Semi-Automatic       4395
# 7   8       320d   Sport Line  2015  Electric  Semi-Automatic       1496
# 8   9         X3   Sport Line  2019  Electric          Manual       1998
# 9  10         i8  Luxury Line  2015    Petrol          Manual       1998
#
#    Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom      Owner_Type  \
# 0     395.18     492.04         20.48              68.33          Second
# ...

# %%
df.head(10)

# %% [markdown]
# ## Q.2Shape, columns, datatypes

# %%
print((df.count(), len(df.columns)))
print(df.columns)
df.printSchema()
print(df)
# Out:
# (ID                      100000
# Model_Name              100000
# Variant                 100000
# Year                    100000
# Fuel_Type               100000
# Transmission            100000
# Engine_CC               100000
# Power_BHP               100000
# Torque_Nm               100000
# Mileage_kmpl            100000
# Price_Ex_Showroom       100000
# Owner_Type              100000
# Insurance_Valid_Till    100000
# Location                100000
# Registration_State      100000
# dtype: int64, 15)
# Index(['ID', 'Model_Name', 'Variant', 'Year', 'Fuel_Type', 'Transmission',
#        'Engine_CC', 'Power_BHP', 'Torque_Nm', 'Mileage_kmpl',
#        'Price_Ex_Showroom', 'Owner_Type', 'Insurance_Valid_Till', 'Location',
#        'Registration_State'],
#       dtype='object')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ...

# %%
df.isnull().sum()
# Out:
# ID                      0
# Model_Name              0
# Variant                 0
# Year                    0
# Fuel_Type               0
# Transmission            0
# Engine_CC               0
# Power_BHP               0
# Torque_Nm               0
# Mileage_kmpl            0
# Price_Ex_Showroom       0
# Owner_Type              0
# Insurance_Valid_Till    0
# Location                0
# Registration_State      0
# dtype: int64

# %% [markdown]
# ## Q.3 Missing values

# %%
df.isnull().sum()
# Out:
# ID                      0
# Model_Name              0
# Variant                 0
# Year                    0
# Fuel_Type               0
# Transmission            0
# Engine_CC               0
# Power_BHP               0
# Torque_Nm               0
# Mileage_kmpl            0
# Price_Ex_Showroom       0
# Owner_Type              0
# Insurance_Valid_Till    0
# Location                0
# Registration_State      0
# dtype: int64

# %% [markdown]
# ## Q.4 Filter cars manufactured after 2020.

# %%
df[df['Year'] > 2020]
# Out:
#           ID Model_Name      Variant  Year Fuel_Type Transmission  Engine_CC  \
# 10        11         i8   Sport Line  2024    Diesel       Manual       4395
# 16        17         M4     Standard  2022    Hybrid    Automatic       4395
# 22        23         M4     Standard  2023    Hybrid       Manual       4395
# 24        25         X3   Sport Line  2022    Hybrid    Automatic       1998
# 27        28         X7     Standard  2022    Diesel    Automatic       2993
# ...      ...        ...          ...   ...       ...          ...        ...
# 99986  99987         Z4     Standard  2021    Diesel       Manual       4395
# 99987  99988         X1     Standard  2023    Hybrid       Manual       2993
# 99991  99992         X1  Luxury Line  2023    Hybrid    Automatic       1496
# 99992  99993         Z4      M Sport  2021    Hybrid       Manual       1496
# 99996  99997         Z4   Sport Line  2021  Electric    Automatic       1496
#
# ...

# %% [markdown]
# ## Q.5 List unique car models and fuel types.

# %%
df['Model_Name'].unique()
df['Fuel_Type'].unique()
# Out:
# array(['Electric', 'Hybrid', 'Petrol', 'Diesel'], dtype=object)

# %% [markdown]
# ## Q.6 Count how many cars per fuel type.

# %%
df['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Petrol      25125
# Diesel      25089
# Hybrid      24934
# Electric    24852
# Name: count, dtype: int64

# %% [markdown]
# ## Q.7 Sort dataset by Price_Ex_Showroom descending.

# %%
df.sort_values('Price_Ex_Showroom', ascending=False)
# Out:
#           ID Model_Name      Variant  Year Fuel_Type    Transmission  \
# 86274  86275         X7      M Sport  2024    Petrol          Manual
# 97582  97583         X7      M Sport  2012    Petrol          Manual
# 62468  62469       520d      M Sport  2016    Hybrid  Semi-Automatic
# 94872  94873       320d  Luxury Line  2018    Petrol          Manual
# 57442  57443         M3     Standard  2013    Hybrid  Semi-Automatic
# ...      ...        ...          ...   ...       ...             ...
# 78097  78098       520d       xDrive  2013    Hybrid       Automatic
# 90017  90018       320d   Sport Line  2013  Electric  Semi-Automatic
# 29372  29373         X1     Standard  2012  Electric       Automatic
# 99357  99358       520d      M Sport  2016    Hybrid  Semi-Automatic
# 31867  31868         X3      M Sport  2022    Petrol          Manual
#
#        Engine_CC  Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom  \
# ...

# %% [markdown]
# ## Q.8 Filter only Automatic transmission BMWs.

# %%
df[df['Transmission']=='Automatic']
# Out:
#           ID Model_Name      Variant  Year Fuel_Type Transmission  Engine_CC  \
# 1          2         X5  Luxury Line  2016  Electric    Automatic       1496
# 11        12         X7      M Sport  2019    Hybrid    Automatic       1998
# 14        15         M3     Standard  2017    Hybrid    Automatic       4395
# 16        17         M4     Standard  2022    Hybrid    Automatic       4395
# 20        21         X5   Sport Line  2010    Hybrid    Automatic       1496
# ...      ...        ...          ...   ...       ...          ...        ...
# 99988  99989         X7   Sport Line  2019    Hybrid    Automatic       1496
# 99990  99991         X5       xDrive  2013    Petrol    Automatic       1998
# 99991  99992         X1  Luxury Line  2023    Hybrid    Automatic       1496
# 99996  99997         Z4   Sport Line  2021  Electric    Automatic       1496
# 99997  99998         M4     Standard  2012    Hybrid    Automatic       2993
#
# ...

# %% [markdown]
# ## Q.9 Replace missing mileage values with mean.

# %%
print(df.columns.tolist())
# Out:
# ['ID', 'Model_Name', 'Variant', 'Year', 'Fuel_Type', 'Transmission', 'Engine_CC', 'Power_BHP', 'Torque_Nm', 'Mileage_kmpl', 'Price_Ex_Showroom', 'Owner_Type', 'Insurance_Valid_Till', 'Location', 'Registration_State']

# %% [markdown]
# ## Q.10 Drop rows where Engine_CC is null.

# %%
df.dropna(subset=['Engine_CC'])
# Out:
#            ID Model_Name      Variant  Year Fuel_Type    Transmission  \
# 0           1         X5       xDrive  2019  Electric          Manual
# 1           2         X5  Luxury Line  2016  Electric       Automatic
# 2           3         Z4      M Sport  2012  Electric  Semi-Automatic
# 3           4         X7      M Sport  2013    Hybrid  Semi-Automatic
# 4           5         X7       xDrive  2010  Electric          Manual
# ...       ...        ...          ...   ...       ...             ...
# 99995   99996         Z4   Sport Line  2014    Hybrid  Semi-Automatic
# 99996   99997         Z4   Sport Line  2021  Electric       Automatic
# 99997   99998         M4     Standard  2012    Hybrid       Automatic
# 99998   99999         X7  Luxury Line  2015  Electric          Manual
# 99999  100000       520d  Luxury Line  2020  Electric  Semi-Automatic
#
#        Engine_CC  Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom  \
# ...

# %% [markdown]
# ## Q.11 Group cars by Model_Name and calculate average price.

# %%
df.groupby('Model_Name')['Price_Ex_Showroom'].mean()
# Out:
# Model_Name
# 320d    85.361262
# 520d    85.270653
# M3      85.090345
# M4      85.223891
# X1      84.612881
# X3      85.528270
# X5      85.401622
# X7      84.835493
# Z4      85.307179
# i8      85.086266
# Name: Price_Ex_Showroom, dtype: float64

# %% [markdown]
# ## Q.12 Create a new column Car_Age = 2025 - Year.

# %%
df['Car_Age'] = 2025 - df['Year']

# %% [markdown]
# ## Q.13 Filter cars priced above ₹60 lakh.

# %%
df[df['Price_Ex_Showroom'] > 60]
# Out:
#            ID Model_Name      Variant  Year Fuel_Type    Transmission  \
# 0           1         X5       xDrive  2019  Electric          Manual
# 1           2         X5  Luxury Line  2016  Electric       Automatic
# 2           3         Z4      M Sport  2012  Electric  Semi-Automatic
# 4           5         X7       xDrive  2010  Electric          Manual
# 5           6         X1      M Sport  2012    Petrol          Manual
# ...       ...        ...          ...   ...       ...             ...
# 99994   99995         X1       xDrive  2015    Hybrid          Manual
# 99995   99996         Z4   Sport Line  2014    Hybrid  Semi-Automatic
# 99996   99997         Z4   Sport Line  2021  Electric       Automatic
# 99998   99999         X7  Luxury Line  2015  Electric          Manual
# 99999  100000       520d  Luxury Line  2020  Electric  Semi-Automatic
#
#        Engine_CC  Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom  \
# ...

# %% [markdown]
# ## Q.14 Find top 5 most common cities in the dataset.

# %%
df['Location'].value_counts().head(5)
# Out:
# Location
# Ahmedabad    12668
# Chennai      12549
# Mumbai       12495
# Bangalore    12492
# Delhi        12478
# Name: count, dtype: int64

# %% [markdown]
# ## Q.15 Plot histogram for mileage.

# %%
print(df.columns.tolist())
df.head(10)
# Out:
# ['ID', 'Model_Name', 'Variant', 'Year', 'Fuel_Type', 'Transmission', 'Engine_CC', 'Power_BHP', 'Torque_Nm', 'Mileage_kmpl', 'Price_Ex_Showroom', 'Owner_Type', 'Insurance_Valid_Till', 'Location', 'Registration_State', 'Car_Age']
#    ID Model_Name      Variant  Year Fuel_Type    Transmission  Engine_CC  \
# 0   1         X5       xDrive  2019  Electric          Manual       1496
# 1   2         X5  Luxury Line  2016  Electric       Automatic       1496
# 2   3         Z4      M Sport  2012  Electric  Semi-Automatic       4395
# 3   4         X7      M Sport  2013    Hybrid  Semi-Automatic       4395
# 4   5         X7       xDrive  2010  Electric          Manual       2993
# 5   6         X1      M Sport  2012    Petrol          Manual       2993
# 6   7         M3     Standard  2014    Hybrid  Semi-Automatic       4395
# 7   8       320d   Sport Line  2015  Electric  Semi-Automatic       1496
# 8   9         X3   Sport Line  2019  Electric          Manual       1998
# ...

# %% [markdown]
# ## Q.16 Create a bar chart of fuel type vs average power.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df.groupby('Fuel_Type')['Power_BHP'].mean().plot(kind='bar')
plt.show()

# %% [markdown]
# ## Q.17 Apply .loc[] to update fuel type of electric variants.

# %%
df.loc[df['Model_Name'].str.contains('Electric', na=False), 'Fuel_Type'] = 'Electric'

# %% [markdown]
# ## Q.18 Convert Price_Ex_Showroom from lakh to ₹ value.

# %%
df['Price_Rupees'] = df['Price_Ex_Showroom'] * 100000

# %% [markdown]
# ## Q.19 Find how many cars are older than 10 years.

# %%
(df['Car_Age'] > 10).sum()
# Out:
# np.int64(33320)

# %% [markdown]
# ## Q.20 Count of cars by Owner_Type and Transmission.

# %%
df.groupby(['Owner_Type','Transmission']).size()
# Out:
# Owner_Type      Transmission
# First           Automatic         8487
#                 Manual            8223
#                 Semi-Automatic    8332
# Fourth & Above  Automatic         8256
#                 Manual            8357
#                 Semi-Automatic    8378
# Second          Automatic         8549
#                 Manual            8175
#                 Semi-Automatic    8240
# Third           Automatic         8373
#                 Manual            8248
#                 Semi-Automatic    8382
# dtype: int64

# %% [markdown]
#  ## Q.21 Find maximum BHP in diesel cars.

# %%
df[df['Fuel_Type']=='Diesel']['Power_BHP'].max()
# Out:
# 624.98

# %% [markdown]
# ## Q.22 Plot scatter plot of Engine_CC vs Price.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df.plot.scatter(x='Engine_CC', y='Price_Ex_Showroom')
plt.show()

# %% [markdown]
# ## Q.23 Count number of variants per model.

# %%
df['Model_Name'].value_counts()
# Out:
# Model_Name
# X3      10141
# X7      10132
# X1      10093
# Z4      10026
# M4      10020
# 520d     9985
# M3       9947
# X5       9903
# 320d     9888
# i8       9865
# Name: count, dtype: int64

# %% [markdown]
# ## Q.24 Find car with max and min mileage.

# %%
print(df.columns.tolist())
# Out:
# ['ID', 'Model_Name', 'Variant', 'Year', 'Fuel_Type', 'Transmission', 'Engine_CC', 'Power_BHP', 'Torque_Nm', 'Mileage_kmpl', 'Price_Ex_Showroom', 'Owner_Type', 'Insurance_Valid_Till', 'Location', 'Registration_State', 'Car_Age', 'Price_Rupees']

# %% [markdown]
# ## Q.25 Calculate median price per year.

# %%
df.groupby('Year')['Price_Ex_Showroom'].median()
# Out:
# Year
# 2010    85.990
# 2011    85.585
# 2012    84.855
# 2013    84.930
# 2014    84.840
# 2015    85.570
# 2016    85.460
# 2017    85.020
# 2018    85.090
# 2019    84.850
# 2020    85.150
# 2021    85.890
# 2022    85.265
# 2023    84.850
# 2024    85.240
# Name: Price_Ex_Showroom, dtype: float64

# %% [markdown]
# ## Q.26 Pivot table with Location vs Fuel_Type.

# %%
pd.pivot_table(df,index='Location',columns='Fuel_Type',aggfunc='size',fill_value=0)
# Out:
# Fuel_Type  Diesel  Electric  Hybrid  Petrol
# Location
# Ahmedabad    3210      3220    3095    3143
# Bangalore    3074      3155    3183    3080
# Chennai      3090      3171    3125    3163
# Delhi        3201      3014    3078    3185
# Hyderabad    3149      3069    3054    3168
# Kolkata      3137      3093    3050    3135
# Mumbai       3139      3080    3165    3111
# Pune         3089      3050    3184    3140

# %% [markdown]
# ## Q.27 Create a column Is_Luxury (if Price > ₹70L = Yes).

# %%
df['Is_Luxury'] = df['Price_Ex_Showroom'].apply(lambda x:'Yes' if x>70 else 'No')

# %% [markdown]
# ## Q.28 Remove duplicate rows if any.

# %%
df.drop_duplicates()
# Out:
#            ID Model_Name      Variant  Year Fuel_Type    Transmission  \
# 0           1         X5       xDrive  2019  Electric          Manual
# 1           2         X5  Luxury Line  2016  Electric       Automatic
# 2           3         Z4      M Sport  2012  Electric  Semi-Automatic
# 3           4         X7      M Sport  2013    Hybrid  Semi-Automatic
# 4           5         X7       xDrive  2010  Electric          Manual
# ...       ...        ...          ...   ...       ...             ...
# 99995   99996         Z4   Sport Line  2014    Hybrid  Semi-Automatic
# 99996   99997         Z4   Sport Line  2021  Electric       Automatic
# 99997   99998         M4     Standard  2012    Hybrid       Automatic
# 99998   99999         X7  Luxury Line  2015  Electric          Manual
# 99999  100000       520d  Luxury Line  2020  Electric  Semi-Automatic
#
#        Engine_CC  Power_BHP  Torque_Nm  Mileage_kmpl  Price_Ex_Showroom  \
# ...

# %% [markdown]
# ## Q.29 Apply filter: Diesel + Automatic + Above 200 BHP.

# %%
filtered = df[(df['Fuel_Type']=='Diesel') &
              (df['Transmission']=='Automatic') &
              (df['Power_BHP']>200)]
filtered
# Out:
#           ID Model_Name      Variant  Year Fuel_Type Transmission  Engine_CC  \
# 45        46         X3       xDrive  2016    Diesel    Automatic       1998
# 77        78         Z4  Luxury Line  2019    Diesel    Automatic       1998
# 118      119       520d      M Sport  2011    Diesel    Automatic       1998
# 127      128       520d      M Sport  2016    Diesel    Automatic       1496
# 138      139         Z4  Luxury Line  2024    Diesel    Automatic       4395
# ...      ...        ...          ...   ...       ...          ...        ...
# 99903  99904         Z4       xDrive  2012    Diesel    Automatic       4395
# 99919  99920       320d   Sport Line  2021    Diesel    Automatic       4395
# 99926  99927       520d     Standard  2021    Diesel    Automatic       1998
# 99934  99935         M3  Luxury Line  2018    Diesel    Automatic       4395
# 99947  99948         X7   Sport Line  2012    Diesel    Automatic       1998
#
# ...

# %% [markdown]
# ## Q.30 Export filtered data to new CSV.

# %%
print(df.columns.tolist())
filtered_df.to_csv('BMW_Filtered_Output.csv', index=False)
# Out:
# ['ID', 'Model_Name', 'Variant', 'Year', 'Fuel_Type', 'Transmission', 'Engine_CC', 'Power_BHP', 'Torque_Nm', 'Mileage_kmpl', 'Price_Ex_Showroom', 'Owner_Type', 'Insurance_Valid_Till', 'Location', 'Registration_State', 'Car_Age', 'Price_Rupees', 'Is_Luxury']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 2
#       1 print(df.columns.tolist())
# ----> 2 filtered_df.to_csv('BMW_Filtered_Output.csv', index=False)
#
# NameError: name 'filtered_df' is not defined
